# %% [markdown]
# # 上个月污染特征与溯源分析报告
#
# ## 分析时间范围
# - 目标月份：2026年3月
# - 同比月份：2025年3月
# - 环比月份：2026年2月

# %% [markdown]
# ## TOP3城市
# - 佛山
# - 湛江
# - 广州

# %% [markdown]
# ## 统计摘要
#
# ### 佛山（2026年3月）
# - PM2.5均值：20.9 μg/m³
# - PM10均值：33.9 μg/m³
# - O3均值：110.2 μg/m³
# - AQI均值：88.2
#
# ### 湛江（2026年3月）
# - PM2.5均值：24.0 μg/m³
# - PM10均值：36.7 μg/m³
# - O3均值：111.9 μg/m³
# - AQI均值：89.5
#
# ### 广州（2026年3月）
# - PM2.5均值：22.2 μg/m³
# - PM10均值：37.1 μg/m³
# - O3均值：112.2 μg/m³
# - AQI均值：89.8

# %% [markdown]
# ## 图表列表
# - 时间序列分析：http://localhost:5174/reports/time_series_analysis.png
# - 空间对比分析：http://localhost:5174/reports/spatial_comparison.png
# - 相关性热图：http://localhost:5174/reports/correlation_heatmap.png

# %%
# 加载并显示图表
import matplotlib.pyplot as plt
from IPython.display import Image, display

# 显示时间序列图
display(Image('http://localhost:5174/reports/time_series_analysis.png'))

# 显示空间对比图
display(Image('http://localhost:5174/reports/spatial_comparison.png'))

# 显示相关性热图
display(Image('http://localhost:5174/reports/correlation_heatmap.png'))
